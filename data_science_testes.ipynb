# %% [markdown]
# <a href="https://colab.research.google.com/github/eduardamota/math-statistics-algebra/blob/main/data_science_testes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
tmdb = pd.read_csv('tmdb_5000_movies.csv')
tmdb.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
tmdb.describe()
# Out:
#              budget             id   popularity       revenue      runtime  \
# count  4.803000e+03    4803.000000  4803.000000  4.803000e+03  4801.000000
# mean   2.904504e+07   57165.484281    21.492301  8.226064e+07   106.875859
# std    4.072239e+07   88694.614033    31.816650  1.628571e+08    22.611935
# min    0.000000e+00       5.000000     0.000000  0.000000e+00     0.000000
# 25%    7.900000e+05    9014.500000     4.668070  0.000000e+00    94.000000
# 50%    1.500000e+07   14629.000000    12.921594  1.917000e+07   103.000000
# 75%    4.000000e+07   58610.500000    28.313505  9.291719e+07   118.000000
# max    3.800000e+08  459488.000000   875.581305  2.787965e+09   338.000000
#
#        vote_average    vote_count
# count   4803.000000   4803.000000
# mean       6.092172    690.217989
# std        1.194612   1234.585891
# min        0.000000      0.000000
# 25%        5.600000     54.000000
# 50%        6.200000    235.000000
# 75%        6.800000    737.000000
# ...

# %%
import seaborn as sns
ax= sns.distplot(tmdb.vote_average, norm_hist= True)
ax.set(xlabel = "Nota Média", ylabel = "Densidade")
ax.set_title("Média de votos por filme")
# Out:
# <ipython-input-3-76d439b164b5>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax= sns.distplot(tmdb.vote_average, norm_hist= True)
# Text(0.5, 1.0, 'Média de votos por filme')

# %%
#Mostrando frequência
import seaborn as sns
ax= sns.distplot(tmdb.vote_average, norm_hist= False, kde=False)
ax.set(xlabel = "Nota Média", ylabel = "Frequência")
ax.set_title("Média de votos por filme")
# Out:
# <ipython-input-4-dfcebddcd327>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax= sns.distplot(tmdb.vote_average, norm_hist= False, kde=False)
# Text(0.5, 1.0, 'Média de votos por filme')

# %%
grafico = sns.boxplot(x=tmdb.vote_average)
grafico.set_title('Nota Média dos Filme')
# Out:
# Text(0.5, 1.0, 'Nota Média dos Filme')

# %% [markdown]
# Valor estranho na nossa amostra, temos filmes que tiveram a média de votos igual a 0.

# %%
tmdb.query('vote_average==0')
# Out:
#        budget                                             genres  \
# 1464        0  [{"id": 18, "name": "Drama"}, {"id": 80, "name...
# 3669        0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 3670        0                  [{"id": 10751, "name": "Family"}]
# 3852        0                      [{"id": 18, "name": "Drama"}]
# 3855  3500000                [{"id": 99, "name": "Documentary"}]
# ...       ...                                                ...
# 4769        0  [{"id": 28, "name": "Action"}, {"id": 37, "nam...
# 4771        0                     [{"id": 27, "name": "Horror"}]
# 4780        0  [{"id": 53, "name": "Thriller"}, {"id": 80, "n...
# 4785        0                      [{"id": 18, "name": "Drama"}]
# 4794        0  [{"id": 53, "name": "Thriller"}, {"id": 27, "n...
#
#                            homepage      id  \
# 1464                            NaN  310706
# 3669  http://www.romeothemovie.com/  113406
# 3670                            NaN  447027
# ...

# %%
tmdb_mais10_votos = tmdb.query('vote_count>=10')
tmdb_mais10_votos.describe()
# Out:
#              budget             id   popularity       revenue      runtime  \
# count  4.392000e+03    4392.000000  4392.000000  4.392000e+03  4391.000000
# mean   3.164545e+07   49204.119991    23.448815  8.990969e+07   108.430881
# std    4.162736e+07   80136.249777    32.592158  1.682870e+08    21.014719
# min    0.000000e+00       5.000000     0.011697  0.000000e+00     0.000000
# 25%    2.895962e+06    8403.500000     6.512166  1.365700e+04    95.000000
# 50%    1.700000e+07   13084.500000    14.827784  2.685837e+07   105.000000
# 75%    4.200000e+07   46831.250000    30.258282  1.022818e+08   118.500000
# max    3.800000e+08  417859.000000   875.581305  2.787965e+09   338.000000
#
#        vote_average    vote_count
# count   4392.000000   4392.000000
# mean       6.226935    754.441712
# std        0.893215   1272.263761
# min        1.900000     10.000000
# 25%        5.700000     83.750000
# 50%        6.300000    288.500000
# 75%        6.800000    831.000000
# ...

# %%
ax= sns.distplot(tmdb_mais10_votos .vote_average)
ax.set(xlabel = "Nota Média", ylabel = "Densidade")
ax.set_title("Média de votos por filme")
# Out:
# <ipython-input-8-1a0a7c225f35>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax= sns.distplot(tmdb_mais10_votos .vote_average)
# Text(0.5, 1.0, 'Média de votos por filme')

# %%
box_plot = sns.boxplot(x=tmdb_mais10_votos.vote_average)
box_plot.set_title('Nota Média dos Filme')
# Out:
# Text(0.5, 1.0, 'Nota Média dos Filme')

# %% [markdown]
# **Vamos analisar as notas do movielens**

# %%
notas = pd.read_csv('ratings.csv')
notas.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
nota_media_filme = notas.groupby("movieId").mean()["rating"]
nota_media_filme.head()
# Out:
# movieId
# 1    3.920930
# 2    3.431818
# 3    3.259615
# 4    2.357143
# 5    3.071429
# Name: rating, dtype: float64

# %%
ax = sns.distplot(nota_media_filme.values)
ax.set(xlabel="Nota Média", ylabel="Densidade")
# Out:
# <ipython-input-12-066f362ca008>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(nota_media_filme.values)
# [Text(0.5, 0, 'Nota Média'), Text(0, 0.5, 'Densidade')]

# %%
qtd_votos_filme = notas.groupby("movieId").count()
filmes_10votos = qtd_votos_filme.query('rating>=10').index
filmes_10votos.values
# Out:
# array([     1,      2,      3, ..., 177765, 179819, 187593])

# %%
nota_media_10votos = nota_media_filme.loc[filmes_10votos.values]
nota_media_10votos.head()
# Out:
# movieId
# 1    3.920930
# 2    3.431818
# 3    3.259615
# 5    3.071429
# 6    3.946078
# Name: rating, dtype: float64

# %%
ax = sns.distplot(nota_media_10votos.values)
ax.set(xlabel="Nota Média", ylabel="Densidade")
# Out:
# <ipython-input-15-1bb3cc39ef8b>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(nota_media_10votos.values)
# [Text(0.5, 0, 'Nota Média'), Text(0, 0.5, 'Densidade')]

# %%
box_plot = sns.boxplot(x=nota_media_10votos.values)
box_plot.set_title("Boxplot Notas Média com mais de 10 Votos")
# Out:
# Text(0.5, 1.0, 'Boxplot Notas Média com mais de 10 Votos')

# %%
#hist_kws: Argumentos extras (Vamos pegar o valor acumulado)
ax = sns.distplot(nota_media_10votos.values,
                  hist_kws={'cumulative':True},
                  kde_kws={'cumulative':True})
ax.set(xlabel="Nota Média", ylabel="%Acumulada")
# Out:
# <ipython-input-17-d87c7ee7c81c>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(nota_media_10votos.values,
# [Text(0.5, 0, 'Nota Média'), Text(0, 0.5, '%Acumulada')]

# %% [markdown]
# ##**Analisando outros Campos**

# %%
ax = sns.distplot(tmdb_mais10_votos.vote_count)
ax.set(xlabel="Número de Votos", ylabel="Densidade")
# Out:
# <ipython-input-18-1ed1ca02f43a>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(tmdb_mais10_votos.vote_count)
# [Text(0.5, 0, 'Número de Votos'), Text(0, 0.5, 'Densidade')]

# %%
tmdb.query("budget >0").budget
# Out:
# 0       237000000
# 1       300000000
# 2       245000000
# 3       250000000
# 4       260000000
#           ...
# 4791           13
# 4792        20000
# 4796         7000
# 4798       220000
# 4799         9000
# Name: budget, Length: 3766, dtype: int64

# %% [markdown]
# # **Média dos Filmes com pelo menos 10 votos**

# %%
nota_media_10votos.mean()
# Out:
# 3.4320503405352594

# %%
nota_media_10votos[0:5].mean()
# Out:
# 3.5259741603585653

# %%
#total de notas
import matplotlib.pyplot as plt
medias = list()
for i in range(1, len(nota_media_10votos)):
  medias.append(nota_media_10votos[0:i].mean())
medias

plt.plot(medias)

# %%
import numpy as np

np.random.seed(10)
temp = nota_media_10votos.sample(frac=1)
medias = list()
for i in range(1, len(temp)):
  medias.append(temp[0:i].mean())
medias

plt.plot(medias)

# %%
#Fazendo por list comprehesion
medias = [temp[0:i].mean() for i in range(1, len(temp))]
plt.plot(medias)

# %%
from statsmodels.stats.weightstats import zconfint #z teste
zconfint(nota_media_10votos)
# Out:
# (3.4112459477469557, 3.452854733323563)

# %%
from statsmodels.stats.weightstats import DescrStatsW #t teste
descr_todos_com_10_votos = DescrStatsW(nota_media_10votos)
descr_todos_com_10_votos.tconfint_mean()
# Out:
# (3.411234839229381, 3.4528658418411395)

# %% [markdown]
# Valores são bem parecidos porque quando a amostra é grande e usamos o t teste, ele se aproxima muito do teste normal.

# %%
#Analisando o filme 1
filmes = pd.read_csv('movies.csv')
filmes.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
filmes.query("movieId==1")
# Out:
#    movieId             title                                       genres
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy

# %%
notas1 = notas.query("movieId==1")
notas1.head()
# Out:
#       userId  movieId  rating   timestamp
# 0          1        1     4.0   964982703
# 516        5        1     4.0   847434962
# 874        7        1     4.5  1106635946
# 1434      15        1     2.5  1510577970
# 1667      17        1     4.5  1305696483

# %%
ax = sns.displot(notas1.rating)
ax.set(xlabel = "Nota", ylabel= "Densidade")
ax.set_titles("Notas para o Tou Story")

# %%
ax2 = sns.boxplot(x=notas1['rating'])
ax2.set(xlabel="Nota")
ax2.set_title("Notas Toy Story")
# Out:
# Text(0.5, 1.0, 'Notas Toy Story')

# %%
notas.rating.mean()
# Out:
# 3.501556983616962

# %%
notas1.rating.count()
# Out:
# 215

# %%
zconfint(notas1.rating)
# Out:
# (3.8093359183563402, 4.032524546759939)

# %%
from statsmodels.stats.weightstats import ztest

# %%
ztest(notas1.rating, value =3.420368675682846 )
# Out:
# (8.791510844779696, 1.475619785279276e-18)

# %% [markdown]
# Temos um p-valor muito pequeno, ou seja, descartamos a hipótese nula de que a média é igual a 3.42

# %%
np.random.seed(20)
temp = notas1.sample(frac=1).rating
def calcula_teste(i):
  media = temp[0:i].mean()
  stat,p = ztest(temp[0:i],value=3.420368675682846)
  return (i,media,p)
medias = np.array([calcula_teste(i) for i in range(2, len(temp))])
medias
plt.plot(medias[:,0],medias[:,1])
plt.plot(medias[:,0],medias[:,2])
plt.hlines(y=0.05,xmin=2,xmax=len(temp), colors='r')
# Out:
# /usr/local/lib/python3.10/dist-packages/statsmodels/stats/weightstats.py:748: RuntimeWarning: divide by zero encountered in double_scalars
#   zstat = (value1 - value2 - diff) / std_diff

# %% [markdown]
# #**Comparação entre duas amostras**

# %%
zconfint(notas1.rating, notas.rating)
# Out:
# (0.2799245129192442, 0.5588219849631111)

# %%
ztest(notas1.rating, notas.rating)
# Out:
# (5.894327101501841, 3.762112778881965e-09)

# %%
from scipy.stats import ttest_ind
ttest_ind(notas1.rating, notas.rating)
# Out:
# TtestResult(statistic=5.894327101501841, pvalue=3.774003138720876e-09, df=101049.0)

# %%
import statsmodels as sm
sm.__version__
# Out:
# '0.14.0'

# %%
descr_todas_notas = DescrStatsW(notas.rating)
descr_toystory = DescrStatsW(notas.rating)
comparacao = descr_todas_notas.get_compare(descr_toystory)
comparacao.summary()
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
plt.boxplot([notas.rating, notas1.rating],labels=["Todos as notas", "Toy Story"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7ee466f57a60>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7ee466f57fa0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7ee466f577f0>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x7ee466f8c520>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7ee466f8c7c0>,
# ...
#  'means': []}

# %% [markdown]
# #**Comparando Filmes**

# %%
filmes.query("movieId in[1,593,72226]")
# Out:
#       movieId                             title  \
# 0           1                  Toy Story (1995)
# 510       593  Silence of the Lambs, The (1991)
# 7180    72226          Fantastic Mr. Fox (2009)
#
#                                            genres
# 0     Adventure|Animation|Children|Comedy|Fantasy
# 510                         Crime|Horror|Thriller
# 7180    Adventure|Animation|Children|Comedy|Crime

# %%
notas593= notas.query("movieId==593")
notas72226= notas.query("movieId==72226")
plt.boxplot([notas1.rating,notas593.rating,notas72226.rating], labels=["Toy Story","Silence of the Lambs","Fantastic Mr. Fox"])
plt.title("Distribuição das Notas por Filme")
# Out:
# Text(0.5, 1.0, 'Distribuição das Notas por Filme')

# %%
notas72226.describe()
# Out:
#            userId  movieId     rating     timestamp
# count   18.000000     18.0  18.000000  1.800000e+01
# mean   329.722222  72226.0   4.083333  1.395218e+09
# std    174.748157      0.0   0.895249  9.459862e+07
# min     73.000000  72226.0   1.500000  1.262899e+09
# 25%    167.000000  72226.0   4.000000  1.279706e+09
# 50%    326.000000  72226.0   4.250000  1.441777e+09
# 75%    466.250000  72226.0   4.500000  1.471770e+09
# max    610.000000  72226.0   5.000000  1.498522e+09

# %%
#Usando agora matplotlib
sns.boxplot(x= "movieId",y="rating",data = notas.query("movieId in (1,593,72226)"))
# Out:
# <Axes: xlabel='movieId', ylabel='rating'>

# %% [markdown]
# Queremos saber se há diferença entre as notas do filme 1 e do 593

# %%
descr_1 = DescrStatsW(notas1.rating)
descr_593 = DescrStatsW(notas593.rating)
comparacao = descr_1.get_compare(descr_593)
comparacao.summary()
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
descr_72226 = DescrStatsW(notas72226.rating)
descr_593 = DescrStatsW(notas593.rating)
comparacao = descr_72226.get_compare(descr_593)
comparacao.summary()
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
notas.query("movieId in (1,593,72226)").groupby("movieId").count()
# Out:
#          userId  rating  timestamp
# movieId
# 1           215     215        215
# 593         279     279        279
# 72226        18      18         18

# %%
#Como temos um valor pequeno no 72226, usamos o teste t
descr_72226 = DescrStatsW(notas72226.rating)
descr_593 = DescrStatsW(notas593.rating)
comparacao = descr_72226.get_compare(descr_593)
comparacao.summary(use_t=True)
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
#Verificando se os meus dados seguem ums distribuição normal
from scipy.stats import normaltest

stat,p = normaltest(notas1.rating)
print(p)
# Out:
# 0.00011053430732728716

# %% [markdown]
# Vemos que o teste não segue a distribuição normal, logo, nesse caso vamos utilizar testes não paramétricos

# %%
#Teste Wilconx
from scipy.stats import ranksums
_,p = ranksums(notas1.rating,notas593.rating)
p
# Out:
# 0.0003267718756440693

# %% [markdown]
# No teste Wilconx temos que na hipótese nula as duas amoastra tem a mesma distribuição, já a hipótese nula nos diz que os valores de uma amostra são maiores que os de outra amostra.
